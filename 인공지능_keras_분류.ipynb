# %% [markdown]
# # 회귀 복습

# %% [markdown]
# ### 데이터 준비

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

num_sample = 1000

X = np.random.uniform(-2, 0.5, num_sample)

Y = 2*X**2 + 3*X + 5
# Y = 1.0/(1.0+np.exp(-X))

Y = Y + 0.1*np.random.randn(num_sample)

# 학습데이터와 테스트데이터로 분리
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2, random_state=24)

plt.plot(X_train, Y_train, 'b.')
plt.plot(X_test, Y_test, 'r.')
plt.show()

# %% [markdown]
# ### 모델 개발

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 모델 생성
model = Sequential()
model.add(Dense(16, input_dim=1))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# 모델 학습
model.fit(X_test, Y_test, epochs=100)

# 모델 활용
#Y_pred = model.predict(X_test)

# 시각화
plt.plot(X_train, Y_train, 'b.')
plt.plot(X_test, Y_test, 'r.')
plt.plot(X_test, Y_pred, 'y.')
plt.show()

# %% [markdown]
# # 분류예측

# %% [markdown]
# ## 이진 분류

# %% [markdown]
# ### 피마 인디언 당뇨병 예측

# %% [markdown]
# ```
# # 컬럼 의미
# pregnancies: 임신 횟수
# plasma: 포도당 부하 검사 수치
# pressure: 혈압(mm Hg)
# thickness: 팔 삼두근 뒤쪽의 피하지방 측정값(mm)
# insulin: 혈청 인슐린(mu U/ml)
# bmi: 체질량지수(체중(kg)/키(m))^2
# pedigree: 당뇨 내력 가중치 값
# age: 나이
# diabetes: 당뇨병 유무 (0 또는 1)
# ```
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# 데이터 셋 준비 피마 인디언 당뇨병 데이터셋
pima = pd.read_csv('https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/pima-indians-diabetes3.csv')

# %% [markdown]
# ### 데이터 확인해 보기

# %%
# 행과 열의 개수, 샘플과 피쳐의 개수
pima.shape

# %%
pima.head()
# pima.tail() 밑에 5개

# %%
# 항목별 데이터 개수, 결측치 개수, 자료형 등 파악
pima.info()

# %% [markdown]
# ### 분류 예측 모델 만들기 - 당뇨병에 걸렸다, 걸리지 않았다.

# %%
# 모듈 불러오기
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 데이터 준비(피마 인디언 당뇨병 데이터셋)
pima = pd.read_csv('https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/pima-indians-diabetes3.csv')

# 전체 컬럼명 : pima.columns 명령을 통해 얻어 낼 수 있음.
# 'pregnant', 'plasma', 'pressure', 'thickness', 'insulin', 'bmi', 'pedigree', 'age', 'diabetes'

X = pima[???]
Y = pima[???]

# %%
# 이진 모델을 설계
model = Sequential()
model.add( Dense(12, input_dim=8, activation='?') )
model.add( Dense(16, activation='?') )
model.add( Dense(8, activation='?') )
model.add( Dense(1, activation='?') )

# 모델 설정
model.compile(optimizer='adam', loss='?', metrics=['accuracy'])

# %%
# 모델 학습
model.fit(X, Y, epochs=1000)

# %%
# 모델 예측
model.predict(X[:5])

# %%
# 실제 결과
Y[:5]

# %% [markdown]
# ## 다항 분류

# %% [markdown]
# ### 꽃의 분류
# 꽃잎길이, 꽃잎폭, 꽃받침길이, 꽃받침폭 --> setosa, virsicolor, virginica
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 데이터 불러오기 및 확인하기

# %%
import pandas as pd

# 데이터 불러오기
iris = pd.read_csv('https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/iris.csv')

# %%
iris
# Out:
#      꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭         품종
# 0     5.1  3.5    1.4   0.2     setosa
# 1     4.9  3.0    1.4   0.2     setosa
# 2     4.7  3.2    1.3   0.2     setosa
# 3     4.6  3.1    1.5   0.2     setosa
# 4     5.0  3.6    1.4   0.2     setosa
# ..    ...  ...    ...   ...        ...
# 145   6.7  3.0    5.2   2.3  virginica
# 146   6.3  2.5    5.0   1.9  virginica
# 147   6.5  3.0    5.2   2.0  virginica
# 148   6.2  3.4    5.4   2.3  virginica
# 149   5.9  3.0    5.1   1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 붓꽃(iris) 분류 - setosa, versicolor, virginica 로 분류

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 데이터 준비
iris = pd.read_csv('https://raw.githubusercontent.com/ygcho-git/basic_AI/main/dataset/iris.csv')

# 데이터 독립변수와 종속변수로 나누기
  # '꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종
X = iris[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
Y = iris['품종']

# %% [markdown]
# ### 데이터 확인하기

# %%
iris.head()
#iris.tail()
#iris()

# %%
iris.shape

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Y(종속) 값을 원핫인코딩
Y = pd.get_dummies(Y)

# %% [markdown]
# ### 다층 신경망 모델 설계하기

# %%
# 모델 설계
model = Sequential()
model.add(Dense(10, input_dim=4, activation='?'))
model.add(Dense(16, activation='?'))
model.add(Dense(16, activation='?'))
model.add(Dense(?, activation='?'))

# 모델 설정
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')

# 모델 학습
model.fit(X, Y, epochs=10)

# %%
# 모델 예측하기
model.predict(X[:5])

# %%
Y[:5]
